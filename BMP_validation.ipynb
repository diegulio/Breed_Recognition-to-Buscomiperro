# %% [markdown]
# <a href="https://colab.research.google.com/github/diegulio/Breed_Recognition-to-Buscomiperro/blob/main/BMP_validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import os

import cv2
from google.colab.patches import cv2_imshow
import pickle as pkl
import matplotlib.pyplot as plt

# %%
a_file = open("class_indices-v3.pkl", "rb")
class_indices = pkl.load(a_file)
a_file.close()

# %%
class_indices
# Out:
# {'Akita': 0,
#  'Bulldog_Ingles': 1,
#  'Dalmata': 2,
#  'No detectado': 3,
#  'affenpinscher': 4,
#  'afghan_hound': 5,
#  'african_hunting_dog': 6,
#  'airedale': 7,
#  'appenzeller': 8,
#  'australian_terrier': 9,
#  'basenji': 10,
#  'basset': 11,
#  'beagle': 12,
#  'bedlington_terrier': 13,
#  'bernese_mountain_dog': 14,
#  'black-and-tan_coonhound': 15,
#  'blenheim_spaniel': 16,
#  'bloodhound': 17,
#  'bluetick': 18,
#  'border_collie': 19,
#  'border_terrier': 20,
#  'borzoi': 21,
#  'boston_bull': 22,
#  'bouvier_des_flandres': 23,
#  'boxer': 24,
#  'brabancon_griffon': 25,
#  'briard': 26,
#  'brittany_spaniel': 27,
#  'bull_mastiff': 28,
#  'cairn': 29,
#  'cardigan': 30,
#  'chesapeake_bay_retriever': 31,
#  'chihuahua': 32,
#  'chow': 33,
#  'clumber': 34,
#  'cocker_spaniel': 35,
#  'collie': 36,
#  'curly-coated_retriever': 37,
#  'dandie_dinmont': 38,
#  'dhole': 39,
#  'dingo': 40,
#  'doberman': 41,
#  'english_foxhound': 42,
#  'english_setter': 43,
#  'entlebucher': 44,
#  'flat-coated_retriever': 45,
#  'french_bulldog': 46,
#  'gato': 47,
#  'german_shepherd': 48,
#  'german_short-haired_pointer': 49,
#  'golden_retriever': 50,
#  'gordon_setter': 51,
#  'great_dane': 52,
#  'great_pyrenees': 53,
#  'greater_swiss_mountain_dog': 54,
#  'groenendael': 55,
#  'ibizan_hound': 56,
#  'irish_setter': 57,
#  'irish_terrier': 58,
#  'irish_water_spaniel': 59,
#  'irish_wolfhound': 60,
#  'italian_greyhound': 61,
#  'japanese_spaniel': 62,
#  'keeshond': 63,
#  'kelpie': 64,
#  'kerry_blue_terrier': 65,
#  'komondor': 66,
#  'kuvasz': 67,
#  'labrador_retriever': 68,
#  'leonberg': 69,
#  'malinois': 70,
#  'maltese_dog': 71,
#  'mexican_hairless': 72,
#  'miniature_pinscher': 73,
#  'newfoundland': 74,
#  'norfolk_terrier': 75,
#  'norwegian_elkhound': 76,
#  'norwich_terrier': 77,
#  'old_english_sheepdog': 78,
#  'otterhound': 79,
#  'papillon': 80,
#  'pekinese': 81,
#  'pembroke': 82,
#  'pomeranian': 83,
#  'poodle': 84,
#  'pug': 85,
#  'redbone': 86,
#  'rhodesian_ridgeback': 87,
#  'rottweiler': 88,
#  'saint_bernard': 89,
#  'saluki': 90,
#  'samoyed': 91,
#  'schipperke': 92,
#  'schnauzer': 93,
#  'scotch_terrier': 94,
#  'scottish_deerhound': 95,
#  'sealyham_terrier': 96,
#  'shih-tzu': 97,
#  'siberian_husky': 98,
#  'silky_terrier': 99,
#  'soft-coated_wheaten_terrier': 100,
#  'springer_spaniel': 101,
#  'staffordshire_terrier': 102,
#  'sussex_spaniel': 103,
#  'tibetan_mastiff': 104,
#  'tibetan_terrier': 105,
#  'toy_terrier': 106,
#  'vizsla': 107,
#  'weimaraner': 108,
#  'west_highland_white_terrier': 109,
#  'whippet': 110,
#  'wire-haired_fox_terrier': 111,
#  'yorkshire_terrier': 112}

# %% [markdown]
# # Models
# Se debe descomentar el modelo que se desea seleccionar, debido a su tamaño es que se recomienda no deseleccionarlos todos

# %%
#model_0 = tf.keras.models.load_model('/content/drive/MyDrive/Colab Data/Proyecto buscomiperro/modelos/invv3_98_84.h5')
#model_3 = tf.keras.models.load_model('/content/drive/MyDrive/Colab Data/Proyecto buscomiperro/modelos/Incv3_082_087.h5')
#model_4 = tf.keras.models.load_model('/content/drive/MyDrive/Colab Data/Proyecto buscomiperro/modelos/Incv3_090_087.h5')
#model_5 = tf.keras.models.load_model('/content/drive/MyDrive/Colab Data/Proyecto buscomiperro/modelos/Incv3_091_087.h5')
model_v3 = tf.keras.models.load_model('/content/drive/MyDrive/Colab Data/Proyecto buscomiperro/modelos/model_v3-Finetune.h5')
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
target_size = {
    'model_v3' : (600,600)
}

# %% [markdown]
# # Validation Kaggle

# %%
val = pd.read_csv('sample_submission.csv')
val['id'] += '.jpg'
val
# Out:
#                                          id  ...  yorkshire_terrier
# 0      000621fb3cbb32d8935728e48679680e.jpg  ...           0.008333
# 1      00102ee9d8eb90812350685311fe5890.jpg  ...           0.008333
# 2      0012a730dfa437f5f3613fb75efcd4ce.jpg  ...           0.008333
# 3      001510bc8570bbeee98c8d80c8a95ec1.jpg  ...           0.008333
# 4      001a5f3114548acdefa3d4da05474c2e.jpg  ...           0.008333
# ...                                     ...  ...                ...
# 10352  ffeda8623d4eee33c6d1156a2ecbfcf8.jpg  ...           0.008333
# 10353  fff1ec9e6e413275984966f745a313b0.jpg  ...           0.008333
# 10354  fff74b59b758bbbf13a5793182a9bbe4.jpg  ...           0.008333
# 10355  fff7d50d848e8014ac1e9172dc6762a3.jpg  ...           0.008333
# 10356  fffbff22c1f51e3dc80c4bf04089545b.jpg  ...           0.008333
#
# [10357 rows x 121 columns]

# %%
def val_model(model):
  from keras_preprocessing.image import ImageDataGenerator

  val_datagen=ImageDataGenerator(rescale=1./255)
  val_generator=val_datagen.flow_from_dataframe(
  dataframe=val,
  directory="/content/drive/MyDrive/Colab Data/Proyecto buscomiperro/val",
  x_col="id",
  y_col=None,
  batch_size=1,
  seed=42,
  shuffle=False,
  class_mode=None,
  target_size=(375,500))
  STEP_SIZE_VAL=val_generator.n//val_generator.batch_size

  y_pred = model.predict(val_generator, steps=STEP_SIZE_VAL, verbose = 1)

  sample_data = pd.read_csv('sample_submission.csv')

  y_prediction = np.delete(y_pred, [0,47], axis = 1) # sin gato ni No detectado

  sample_data.iloc[:,1:] = y_prediction

  sample_data.to_csv('sub.csv', index = False)

  return None

# %%
val_model(model_0)
# Out:
# Found 10357 validated image filenames.
# 10357/10357 [==============================] - 6300s 608ms/step

# %% [markdown]
# # Single Validation

# %%
def view_probs(path_img, model= model_v3, model_name = 'model_v3'):


  img = load_img(path_img, target_size= target_size[model_name])
  plt.imshow(img)

  # x = img_to_array(img).reshape(-1, 375, 500, 3)/255  Esto para formato antiguo (models v1 hacia atrás)
  x = tf.expand_dims(img_to_array(img), axis = 0) # (models v2 hacia adelante no es necesario /255)

  pred = model.predict(x)[0]

  best_3 = pred.argsort()[-3:][::-1] # Se obtienen los indices de los mejores 3 valores de pred

  print('=============================')
  print('                Raza| Prob')
  print('--------------------------')
  for idx_breed in best_3:
    # Nombre de breed
    for breed, idx  in class_indices.items():
      if idx == idx_breed:
          breed_pred = breed

    print('%20s| %4.2f'%(breed_pred, pred[idx_breed]))

  print('=============================')

  return None

# %%
path_img = '/content/perro.jpeg' # El path de tu imagen
view_probs(path_img)
# Out:
# =============================
#                 Raza| Prob
# --------------------------
#       siberian_husky| 0.47
#                Akita| 0.37
# staffordshire_terrier| 0.04
# =============================
